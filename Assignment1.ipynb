# %% [markdown]
# <a href="https://colab.research.google.com/github/prathyushagorantla9-netizen/prathyusha/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
bank = [
    [ # Bank 1
        [ # Branch 1 of Bank 1
            ["C101", "Rahul", "Savings", 85000],
            ["C102", "Anita", "Current", 150000],
            ["C103", "Kiran", "Loan", 500000]
        ],
        [ # Branch 2 of Bank 1
            ["C104", "Sneha", "Savings", 95000],
            ["C105", "Vikram", "Current", 275000],
            ["C106", "Meena", "Loan", 750000]
        ]
    ],
    [ # Bank 2
        [ # Branch 1 of Bank 2
            ["C201", "Arjun", "Savings", 120000],
            ["C202", "Pooja", "Current", 325000],
            ["C203", "Ramesh", "Loan", 900000]
        ],
        [ # Branch 2 of Bank 2
            ["C204", "Priya", "Savings", 45000],
            ["C205", "Amit", "Current", 185000],
            ["C206", "Divya", "Loan", 650000]
        ]
    ],
    [ # Bank 3
        [ # Branch 1 of Bank 3
            ["C301", "Nikhil", "Savings", 78000],
            ["C302", "Kavya", "Current", 240000],
            ["C303", "Suresh", "Loan", 1000000]
        ],
        [ # Branch 2 of Bank 3
            ["C304", "Neha", "Savings", 135000],
            ["C305", "Rohan", "Current", 410000],
            ["C306", "Asha", "Loan", 550000]
        ]
    ]
]

# %%
'''Print Rahul's complete record.

Print Anita's account type.

Print Kiran's loan amount.

Print Sneha's customer ID.

Print Vikram's balance.

Print Meena's complete record.

Print Arjun's customer ID.

Print Pooja's name.

Print Ramesh's account type.

Print Priya's balance.

Print Amit's account type.

Print Divya's customer ID.

Print Nikhil's account type.

Print Kavya's balance.

Print Suresh's loan amount.

Print Neha's name.

Print Rohan's complete record.

Print Asha's account type.

Print all customers in Bank 1, Branch 1.

Print all customers in Bank 1, Branch 2.

Print all customers in Bank 2, Branch 1.

Print all customers in Bank 2, Branch 2.

Print all customers in Bank 3, Branch 1.

Print all customers in Bank 3, Branch 2.

Print all branches of Bank 1.

Print all branches of Bank 2.

Print all branches of Bank 3.

Print the first customer from every bank's first branch.

Print the second customer from every bank's second branch.

Print the loan amount of the last customer in Bank 3, Branch 2.
     '''
# Out:
# "Print Rahul's complete record.\n\nPrint Anita's account type.\n\nPrint Kiran's loan amount.\n\nPrint Sneha's customer ID.\n\nPrint Vikram's balance.\n\nPrint Meena's complete record.\n\nPrint Arjun's customer ID.\n\nPrint Pooja's name.\n\nPrint Ramesh's account type.\n\nPrint Priya's balance.\n\nPrint Amit's account type.\n\nPrint Divya's customer ID.\n\nPrint Nikhil's account type.\n\nPrint Kavya's balance.\n\nPrint Suresh's loan amount.\n\nPrint Neha's name.\n\nPrint Rohan's complete record.\n\nPrint Asha's account type.\n\nPrint all customers in Bank 1, Branch 1.\n\nPrint all customers in Bank 1, Branch 2.\n\nPrint all customers in Bank 2, Branch 1.\n\nPrint all customers in Bank 2, Branch 2.\n\nPrint all customers in Bank 3, Branch 1.\n\nPrint all customers in Bank 3, Branch 2.\n\nPrint all branches of Bank 1.\n\nPrint all branches of Bank 2.\n\nPrint all branches of Bank 3.\n\nPrint the first customer from every bank's first branch.\n\nPrint the second customer from every bank's second branch.\n\nPrint the loan amount of the last customer in Bank 3, Branch 2.\n     "

# %%
# Print Rahul's complete record.
print("Rahul's record:", bank[0][0][0])
# Out:
# Rahul's complete record: ['C101', 'Rahul', 'Savings', 85000]

# %%
#Print Anita's account type
print("Anitha's account type:", bank[0][0][1][2])
# Out:
# Anitha's account type: Current

# %%
#Print Kiran's loan amount.
print("Kiran's loan amount:",bank[0][0][2][3])
# Out:
# Kiran's loan amount: 500000

# %%
#Print Sneha's customer ID.
print("Sneha customer ID:", bank[0][1][0][0])
# Out:
# Sneha customer ID: C104

# %%
#Print Vikram's balance.
print("Vikram's balance:", bank[0][1][1][3])
# Out:
# Vikram's balance: 275000

# %%
#Print Meena's complete record
print("Meena's complete record:", bank[0][1][2])
# Out:
# Meena's complete record: ['C106', 'Meena', 'Loan', 750000]

# %%
#Print Arjun's customer ID.
print("Arjun's customer ID:", bank[1][0][0])
# Out:
# Arjun's customer ID: ['C201', 'Arjun', 'Savings', 120000]

# %%
#Print Pooja's name.
print("Pooja's name:", bank[1][0][1][1])
# Out:
# Pooja's name: Pooja

# %%
#Print Ramesh's account type
print("Ramesh account type:", bank[1][0][2][2])
# Out:
# Ramesh account type: Loan

# %%
#Print Priya's balance
print("Priya's balance:", bank[1][1][0][3])
# Out:
# Priya's balance: 45000

# %%
#Print Amit's account type
print("Amit's account type:", bank[1][1][1][2])
# Out:
# Amit's account type: Current

# %%
#Print Divya's customer ID.
print("Divya's customer ID:", bank[1][1][2][0])
# Out:
# Divya's customer ID: C206

# %%
#Print Nikhil's account type.
print("Nikhil's account type:", bank[2][0][0][2])
# Out:
# Nikhil's account type: Savings

# %%
#Print Kavya's balance
print("Kavya's balance:", bank[2][0][1][3])
# Out:
# Kavya's balance: 240000

# %%
#Print Suresh's loan amount.
print("Suresh's loan amount:", bank[2][0][2][3])
# Out:
# Suresh's loan amount: 1000000

# %%
#Print Neha's name
print("Neha's name:", bank[2][1][0][1])
# Out:
# Neha's name: Neha

# %%
#Print Rohan's complete record
print("Rohan's complete record:", bank[2][1][1])
# Out:
# Rohan's complete record: ['C305', 'Rohan', 'Current', 410000]

# %%
#Print Asha's account type.
print("Asha's account type:",bank[2][1][2][2])
# Out:
# Asha's account type: Loan

# %%
#Print all customers in Bank 1, Branch 1.
print("All customers in Bank 1, Branch 1:", bank[0][0])
# Out:
# All customers in Bank 1, Branch 1: [['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]]

# %%
#Print all customers in Bank 1, Branch 2.
print("All customers in Bank 1, Branch 2:", bank[0][1])
# Out:
# All customers in Bank 1, Branch 2: [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]

# %%
#Print all customers in Bank 2, Branch 1.
print("All customers in Bank 2, Branch 1:", bank[1][0])
# Out:
# All customers in Bank 2, Branch 1: [['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]]

# %%
#Print all customers in Bank 2, Branch 2.
print("All customers in Bank 2, Branch 2:", bank[1][1])
# Out:
# All customers in Bank 2, Branch 2: [['C204', 'Priya', 'Savings', 45000], ['C205', 'Amit', 'Current', 185000], ['C206', 'Divya', 'Loan', 650000]]

# %%
#Print all customers in Bank 3, Branch 1.
print("All customers in Bank 3, Branch 1:", bank[2][0])
# Out:
# All customers in Bank 3, Branch 1: [['C301', 'Nikhil', 'Savings', 78000], ['C302', 'Kavya', 'Current', 240000], ['C303', 'Suresh', 'Loan', 1000000]]

# %%
#Print all customers in Bank 3, Branch 2.
print("All customers in Bank 3, Branch 2:", bank[2][1])
# Out:
# All customers in Bank 3, Branch 2: [['C304', 'Neha', 'Savings', 135000], ['C305', 'Rohan', 'Current', 410000], ['C306', 'Asha', 'Loan', 550000]]

# %%
#Print all branches of Bank 1
print("All branches of Bank 1:", bank[0])
# Out:
# All branches of Bank 1: [[['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]], [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]]

# %%
#Print all branches of Bank 2
print("All branches of Bank 2:", bank[1])
# Out:
# All branches of Bank 2: [[['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]], [['C204', 'Priya', 'Savings', 45000], ['C205', 'Amit', 'Current', 185000], ['C206', 'Divya', 'Loan', 650000]]]

# %%
#Print all branches of Bank 3
print("All branches of Bank 3:", bank[2])
# Out:
# All branches of Bank 3: [[['C301', 'Nikhil', 'Savings', 78000], ['C302', 'Kavya', 'Current', 240000], ['C303', 'Suresh', 'Loan', 1000000]], [['C304', 'Neha', 'Savings', 135000], ['C305', 'Rohan', 'Current', 410000], ['C306', 'Asha', 'Loan', 550000]]]

# %%
#Print the first customer from every bank's first branch.
print("First customer from Bank 1, Branch 1:", bank[0][0][0])
print("First customer from Bank 2, Branch 1:", bank[1][0][0])
print("First customer from Bank 3, Branch 1:", bank[2][0][0])
# Out:
# First customer from Bank 1, Branch 1: ['C101', 'Rahul', 'Savings', 85000]
# First customer from Bank 2, Branch 1: ['C201', 'Arjun', 'Savings', 120000]
# First customer from Bank 3, Branch 1: ['C301', 'Nikhil', 'Savings', 78000]

# %%
#Print the second customer from every bank's second branch.
print("Second customer from Bank 1, Branch 2:", bank[0][1][1])
print("Second customer from Bank 2, Branch 2:", bank[1][1][1])
print("Second customer from Bank 3, Branch 2:", bank[2][1][1])
# Out:
# First customer from Bank 1, Branch 2: ['C105', 'Vikram', 'Current', 275000]
# First customer from Bank 2, Branch 2: ['C205', 'Amit', 'Current', 185000]
# First customer from Bank 3, Branch 2: ['C305', 'Rohan', 'Current', 410000]

# %%
#Print the loan amount of the last customer in Bank 3, Branch 2.
print("Loan amount of the last customer in Bank 3, Branch 2:", bank[2][1][2][3])
# Out:
# Loan amount of the last customer in Bank 3, Branch 2: 550000

# %%
#Create a list of 5 employee names and add a new employee using append().
x=["Prathyusha","Raghu","Bala","Guru","Balaji"]
x.append("Avyakt")
print(x)
# Out:
# ['Prathyusha', 'Raghu', 'Bala', 'Guru', 'Balaji', 'Avyakt']

# %%
#Create a list of account numbers and add three new account numbers using extend().
a=[1,2,3,4,5,6]
#print(a.extend([10,123,678]))---this is giving NONE---need to check
print(a)
# Out:
# None
# [1, 2, 3, 4, 5, 6, 10, 123, 678]

# %%
#Insert a new customer at the beginning of a customer list using insert().
xy=["Prathyusha","Raghu","Bala","Guru","Balaji"]
xy.insert(0,"Ravi")
print(xy)
# Out:
# ['Ravi', 'Prathyusha', 'Raghu', 'Bala', 'Guru', 'Balaji']

# %%
#Insert a transaction amount at index 3 in a list.
list1=[100,4500,85940,45869,23847,28349,9827,3847]
list1.insert(3,"9999")
print(list1)
# Out:
# [100, 4500, 85940, '9999', 45869, 23847, 28349, 9827, 3847]

# %%
#Remove the last item from a list using pop().
xy=["Prathyusha","Raghu","Bala","Guru","Balaji"]
#xy.pop()---these two are behaving the same
xy.pop(-1)
print(xy)
# Out:
# ['Prathyusha', 'Raghu', 'Bala', 'Guru']

# %%
#Remove the customer "Rahul" from a customer list using remove().
xy=["Prathyusha","Raghu","Bala","Guru","Balaji"]
xy.remove("Bala")
print(xy)
# Out:
# ['Prathyusha', 'Raghu', 'Guru', 'Balaji']

# %%
#Count how many times the account type "Savings" appears in a list using count().
xy=["Savings","Current","Balance","Ravi","Savings","DEONR","savings"]
xy.count("Savings")
# Out:
# 2

# %%
#Find the index of "Current" in a list of account types using index().
xy=["Savings","Current","Balance","Ravi","Savings","DEONR","savings"]
xy.index("Current")
# Out:
# 1

# %%
#Reverse a list of transaction IDs using reverse().
xy=[100,4500,85940,45869,23847,28349,9827,3847]
xy.reverse()
print(xy)
# Out:
# [3847, 9827, 28349, 23847, 45869, 85940, 4500, 100]

# %%
#Sort a list of account balances in ascending order using sort().
xy=[100,4500,85940,45869,23847,28349,9827,3847]
xy.sort(reverse=False)
print(xy)
# Out:
# [100, 3847, 4500, 9827, 23847, 28349, 45869, 85940]

# %%
#Sort a list of account balances in descending order using sort().
xy=[100,4500,85940,45869,23847,28349,9827,3847]
xy.sort(reverse=True)
print(xy)
# Out:
# [85940, 45869, 28349, 23847, 9827, 4500, 3847, 100]

# %%
#Make a copy of a list using copy() and verify that modifying the copied list does not affect the original list.
x=[3,4,7,9,90]
y=x.copy()
y[3]=13
print(x)
print(y)
# Out:
# [3, 4, 7, 9, 90]
# [3, 4, 7, 13, 90]

# %%
##Make a copy of a list and verify that modifying the copied lis affect the original list.
x=[3,4,7,9,90]
y=x
y[3]=13
print(x)
print(y)
# Out:
# [3, 4, 7, 13, 90]
# [3, 4, 7, 13, 90]

# %%
#Clear all elements from a list using clear().
x=[3,4,7,9,90]
x.clear()
print(x)
# Out:
# []

# %%
#Append a nested list containing a new customer's details to an existing customer list.
xy=["Prathyusha","Raghu","Bala","Guru","Balaji"]
xy.append(["Avyakt","Ravi","babu"])
print(xy)
# Out:
# ['Prathyusha', 'Raghu', 'Bala', 'Guru', 'Balaji', ['Avyakt', 'Ravi', 'babu']]

# %%
#Extend a list of branch names with another list of new branches.
xy=["Prathyusha","Raghu","Bala","Guru","Balaji"]
xy.extend(["Babu","Ravi"])
print(xy)
# Out:
# ['Prathyusha', 'Raghu', 'Bala', 'Guru', 'Balaji', 'Babu', 'Ravi']

# %%
#Remove the first occurrence of the balance 50000 from a list using remove().
xy=["Prathyusha","Raghu","Bala","Guru","Balaji"]
xy.remove("Prathyusha")
print(xy)
# Out:
# ['Raghu', 'Bala', 'Guru', 'Balaji']

# %%
#Pop the element at index 2 from a list and print the removed value.
xy=["Prathyusha","Raghu","Bala","Guru","Balaji"]
z=xy.pop(2)
print(xy)
print(z)
# Out:
# ['Prathyusha', 'Raghu', 'Guru', 'Balaji']
# Bala

# %%
#Count how many times the city "Bangalore" appears in a list.
list2=["Bangalore","Pune","Hyd","Bangalore","Chennai","Bangalore","Bangalore","Delhi"]
list2.count("Bangalore")
# Out:
# 4

# %%
#Reverse a list of bank names and print the result
list3=["hdfc","sbi","union"]
list3.reverse()
print(list3)
# Out:
# ['union', 'sbi', 'hdfc']

# %%
#Create a list of loan amounts and sort it in descending order.
loanamount=[34556,56775,98327,23423,12323,67564]
loanamount.sort(reverse=True)
print(loanamount)
# Out:
# [98327, 67564, 56775, 34556, 23423, 12323]

# %%
bank_branches = {"MG Road", "Indiranagar", "Whitefield", "Electronic City"}

customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}

new_customers = {"Amit", "Priya", "Rahul", "Divya"}

loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}

savings_customers = {"Rahul", "Sneha", "Priya", "Nikhil"}

transaction_ids = {101, 102, 103, 104, 105}

balances = {85000, 120000, 45000, 95000, 275000}

cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}

new_cities = {"Mumbai", "Bangalore", "Delhi"}

account_types = {"Savings", "Current", "Loan"}

# %%
#Print the customers set.
print("Customers:", customers)
# Out:
# Customers: {'Vikram', 'Kiran', 'Rahul', 'Sneha', 'Anita'}

# %%
#Find the number of elements in the customers set.
len(customers)
# Out:
# 5

# %%
#Check whether "Rahul" exists in the customers set.
print("Rahul" in customers)
# Out:
# True

# %%
#Check whether "Meena" exists in the customers set.
print("Meena exist in customer:",{"Meena"}. issubset(customers))
print("Meena" in customers)
# Out:
# Meena exist in customer: False
# False

# %%
#Iterate through all elements in the bank_branches set.
for i in bank_branches:
  print(i)
# Out:
# Electronic City
# MG Road
# Indiranagar
# Whitefield

# %%
#Add "Meena" to the customers set.
customers.add("Meena")
print(customers)
# Out:
# {'Vikram', 'Kiran', 'Meena', 'Rahul', 'Sneha', 'Anita'}

# %%
#Add "Mysore" to the cities set.
cities.add("Mysore")
print(cities)
# Out:
# {'Chennai', 'Mysore', 'Hyderabad', 'Mumbai', 'Delhi', 'Bangalore', 'Pune'}

# %%
#Update the customers set with new_customers.
customers.update(new_customers)
print("Customers Updated NEW LIST:",customers)
# Out:
# Customers Updated NEW LIST: {'Amit', 'Anita', 'Vikram', 'Kiran', 'Meena', 'Priya', 'Rahul', 'Sneha', 'Divya'}

# %%
#Update the cities set with new_cities.
#print(cities)
cities.update(new_cities)
print("new_cities: ",cities)
#print("Cities Updated NEW LIST:",cities) #repeated list will get deleted?
# Out:
# new_cities:  {'Hyderabad', 'Delhi', 'Chennai', 'Mysore', 'Mumbai', 'Bangalore', 'Pune'}

# %%
#Remove "Rahul" from the customers set.
customers.remove("Rahul")
print(customers)
# Out:
# {'Amit', 'Anita', 'Vikram', 'Kiran', 'Meena', 'Priya', 'Sneha', 'Divya'}

# %%
#Remove "Pune" from the cities set.
cities.remove("Pune")
print(cities)
# Out:
# {'Hyderabad', 'Delhi', 'Chennai', 'Mysore', 'Mumbai', 'Bangalore'}

# %%
#Discard "Anita" from the customers set.
customers.discard("Anita")
print(customers)
# Out:
# {'Vikram', 'Kiran', 'Rahul', 'Sneha'}

# %%
#Discard "Delhi" from the cities set.
cities.discard("Delhi")
print(cities)
# Out:
# {'Hyderabad', 'Chennai', 'Mysore', 'Mumbai', 'Bangalore'}

# %%
#Discard "Kolkata" from the cities set
cities.discard("Kolkata")
print(cities)
# Out:
# {'Hyderabad', 'Chennai', 'Mysore', 'Mumbai', 'Bangalore'}

# %%
#Remove a random element from the transaction_ids set using pop().
popped_id = transaction_ids.pop()
print(f"Removed Element: {popped_id}")
print(f"Updated Set: {transaction_ids}")
# Out:
# Removed Element: 102
# Updated Set: {103, 104, 105}

# %%
#Remove another random element from the account_types set.
element_id = account_types.pop()
print(f"Removed Element: {element_id}")
print(f"Updated Set: {account_types}")
# Out:
# Removed Element: Savings
# Updated Set: {'Loan', 'Current'}

# %%
#Remove all elements from the balances set.
balances.clear()
print(balances)
# Out:
# set()

# %%
#Create a copy of the customers set.
a=customers.copy()
print(a)
# Out:
# {'Vikram', 'Kiran', 'Rahul', 'Sneha', 'Anita'}

# %%
#Modify the copied set and verify that the original set remains unchanged
b=a.copy()
b.add("Praveen")
print("Old customers list:",a)
print("New customers list:",b)
# Out:
# Old customers list: {'Vikram', 'Kiran', 'Rahul', 'Sneha', 'Anita'}
# New customers list: {'Vikram', 'Kiran', 'Praveen', 'Rahul', 'Sneha', 'Anita'}

# %%
#Find the union of customers and new_customers(UNION)
customers.union(new_customers)
# Out:
# {'Amit', 'Anita', 'Divya', 'Kiran', 'Priya', 'Rahul', 'Sneha', 'Vikram'}

# %%
#Intersection#Find the common customers between customers and new_customers.
print(customers)
print(new_customers)
print("common data:",customers.intersection(new_customers))
# Out:
# {'Vikram', 'Kiran', 'Rahul', 'Sneha', 'Anita'}
# {'Priya', 'Amit', 'Divya', 'Rahul'}
# common data: {'Rahul'}

# %%
#Find customers who have both Savings and Loan accounts
savings_customers.intersection(loan_customers)
# Out:
# {'Rahul'}

# %%
#Find customers present only in customers but not in new_customers.
customers.difference(new_customers)
# Out:
# {'Anita', 'Kiran', 'Sneha', 'Vikram'}

# %%
#Find customers who have only Savings accounts
print(savings_customers)
print(customers)
print("only Savings customers:",savings_customers.difference(customers))
# Out:
# {'Nikhil', 'Priya', 'Rahul', 'Sneha'}
# {'Vikram', 'Kiran', 'Rahul', 'Sneha', 'Anita'}
# only Savings customers: {'Nikhil', 'Priya'}

# %%
#Find customers that are present in either customers or new_customers but not both.
print(customers)
print(new_customers)
print("Unique list:",customers.symmetric_difference(new_customers))
# Out:
# {'Vikram', 'Kiran', 'Rahul', 'Sneha', 'Anita'}
# {'Priya', 'Amit', 'Divya', 'Rahul'}
# Unique list: {'Amit', 'Anita', 'Vikram', 'Priya', 'Kiran', 'Sneha', 'Divya'}

# %%
#Check whether {"Rahul", "Kiran"} is a subset of loan_customers.
customers.issubset({"Rahul","Kiran"})
# Out:
# False

# %%
#Check whether customers is a superset of {"Rahul", "Anita"}.
customers.issuperset({"Rahul", "Anita"})
# Out:
# True

# %%
#check whether loan_customers and new_cities are disjoint.
#loan_customers.isdisjoint(new_cities)
new_cities.isdisjoint(loan_customers)
# Out:
# True

# %%
#Find the maximum balance in the balances set.
max(balances)
# Out:
# 275000

# %%
#Find the minimum balance in the balances set
min(balances)
# Out:
# 45000

# %%
#Find the total of all balances.
sum(balances)
# Out:
# 620000

# %%
#Sort the balances set in ascending order.
sorted(balances)
# Out:
# [45000, 85000, 95000, 120000, 275000]

# %%
#Convert the customers set into a list
abc=__builtins__.list(customers) #when i use list its giving the error
print(abc)
# Out:
# ['Vikram', 'Kiran', 'Rahul', 'Sneha', 'Anita']

# %%
#Convert the cities set into a tuple.
a=tuple(cities)
print(a)
# Out:
# ('Chennai', 'Hyderabad', 'Bangalore', 'Pune')

# %%
#Remove duplicates from the list: ["Rahul", "Rahul", "Anita", "Sneha", "Sneha"] by converting it into a set.
details=["Rahul", "Rahul", "Anita", "Sneha", "Sneha"]
set(details)
# Out:
# {'Anita', 'Rahul', 'Sneha'}

# %%
#Create an empty set.
a=set()
print(a)
# Out:
# set()

# %%
#Add five employee names to the empty set.
names = set()
names.add("Ravi")
names.add("Saritha")
names.add("Uma")
names.add("Manohar")
names.add("Raghav")
print(names)
# Out:
# {'Manohar', 'Uma', 'Ravi', 'Saritha', 'Raghav'}

# %%
#Find the length of the account_types set.
len(account_types)
# Out:
# 3

# %%
#Print every element of the loan_customers set using a loop.
for i in loan_customers:
 print(i)
# Out:
# Asha
# Ramesh
# Kiran
# Rahul

# %%
#Clear the transaction_ids set and verify that it is empty.
tra=transaction_ids.clear()
print(transaction_ids)
print(tra)
# Out:
# set()
# None
